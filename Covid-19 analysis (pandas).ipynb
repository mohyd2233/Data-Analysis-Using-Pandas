# %%
import numpy as np
import pandas as pd
import requests
import urllib
import os

# %%
cov = pd.read_csv('WHO-COVID-19-global-data.csv')

# %%
cov
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 110096    2021-04-08           ZW     Zimbabwe       AFRO         18
# 110097    2021-04-09           ZW     Zimbabwe       AFRO         68
# 110098    2021-04-10           ZW     Zimbabwe       AFRO         95
# 110099    2021-04-11           ZW     Zimbabwe       AFRO        126
# 110100    2021-04-12           ZW     Zimbabwe       AFRO         15
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
cov_index = cov.index
cov_index
# Out:
# RangeIndex(start=0, stop=110101, step=1)

# %%
cov_cols = cov.columns
cov_cols
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
cov.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2021-04-10', 'ZW', 'Zimbabwe', ..., 37147, 3, 1535],
#        ['2021-04-11', 'ZW', 'Zimbabwe', ..., 37273, 3, 1538],
#        ['2021-04-12', 'ZW', 'Zimbabwe', ..., 37288, 0, 1538]],
#       dtype=object)

# %%
cov.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
cov.shape
# Out:
# (110101, 8)

# %%
cov.head(11)
# Out:
#    Date_reported Country_code      Country WHO_region  New_cases  \
# 0     2020-01-03           AF  Afghanistan       EMRO          0
# 1     2020-01-04           AF  Afghanistan       EMRO          0
# 2     2020-01-05           AF  Afghanistan       EMRO          0
# 3     2020-01-06           AF  Afghanistan       EMRO          0
# 4     2020-01-07           AF  Afghanistan       EMRO          0
# 5     2020-01-08           AF  Afghanistan       EMRO          0
# 6     2020-01-09           AF  Afghanistan       EMRO          0
# 7     2020-01-10           AF  Afghanistan       EMRO          0
# 8     2020-01-11           AF  Afghanistan       EMRO          0
# 9     2020-01-12           AF  Afghanistan       EMRO          0
# 10    2020-01-13           AF  Afghanistan       EMRO          0
#
#     Cumulative_cases  New_deaths  Cumulative_deaths
# 0                  0           0                  0
# 1                  0           0                  0
# ...

# %%
cov.tail(11)
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 110090    2021-04-02           ZW  Zimbabwe       AFRO         14
# 110091    2021-04-03           ZW  Zimbabwe       AFRO          8
# 110092    2021-04-04           ZW  Zimbabwe       AFRO          7
# 110093    2021-04-05           ZW  Zimbabwe       AFRO         12
# 110094    2021-04-06           ZW  Zimbabwe       AFRO         11
# 110095    2021-04-07           ZW  Zimbabwe       AFRO         32
# 110096    2021-04-08           ZW  Zimbabwe       AFRO         18
# 110097    2021-04-09           ZW  Zimbabwe       AFRO         68
# 110098    2021-04-10           ZW  Zimbabwe       AFRO         95
# 110099    2021-04-11           ZW  Zimbabwe       AFRO        126
# 110100    2021-04-12           ZW  Zimbabwe       AFRO         15
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 110090             36896           0               1523
# 110091             36904           1               1524
# ...

# %%
cov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110101 entries, 0 to 110100
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      110101 non-null  object
#  1   Country_code       109635 non-null  object
#  2   Country            110101 non-null  object
#  3   WHO_region         110101 non-null  object
#  4   New_cases          110101 non-null  int64
#  5   Cumulative_cases   110101 non-null  int64
#  6   New_deaths         110101 non-null  int64
#  7   Cumulative_deaths  110101 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 6.7+ MB

# %%
cov.describe()
# Out:
#            New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  110101.000000      1.101010e+05  110101.000000      110101.000000
# mean     1236.277908      1.715815e+05      26.674744        4257.565018
# std      7635.647106      1.127507e+06     150.086777       23303.110448
# min    -32952.000000      0.000000e+00    -514.000000           0.000000
# 25%         0.000000      1.300000e+01       0.000000           0.000000
# 50%         5.000000      1.543000e+03       0.000000          26.000000
# 75%       240.000000      2.963400e+04       4.000000         522.000000
# max    402270.000000      3.088876e+07    6409.000000      556853.000000

# %%
cov['Country']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 110096       Zimbabwe
# 110097       Zimbabwe
# 110098       Zimbabwe
# 110099       Zimbabwe
# 110100       Zimbabwe
# Name: Country, Length: 110101, dtype: object

# %%
cov['Country'].uniquee()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
cov.loc[1:467,'Country']
# Out:
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
# 5      Afghanistan
#           ...
# 463    Afghanistan
# 464    Afghanistan
# 465    Afghanistan
# 466    Afghanistan
# 467        Albania
# Name: Country, Length: 467, dtype: object

# %%
cov.iloc[1:467]
# Out:
#     Date_reported Country_code      Country WHO_region  New_cases  \
# 1      2020-01-04           AF  Afghanistan       EMRO          0
# 2      2020-01-05           AF  Afghanistan       EMRO          0
# 3      2020-01-06           AF  Afghanistan       EMRO          0
# 4      2020-01-07           AF  Afghanistan       EMRO          0
# 5      2020-01-08           AF  Afghanistan       EMRO          0
# ..            ...          ...          ...        ...        ...
# 462    2021-04-09           AF  Afghanistan       EMRO         76
# 463    2021-04-10           AF  Afghanistan       EMRO        125
# 464    2021-04-11           AF  Afghanistan       EMRO         16
# 465    2021-04-12           AF  Afghanistan       EMRO         82
# 466    2021-04-13           AF  Afghanistan       EMRO        122
#
#      Cumulative_cases  New_deaths  Cumulative_deaths
# 1                   0           0                  0
# 2                   0           0                  0
# ...

# %%
cov[cov['Country']=="United States of America"]
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 104967    2020-01-03           US  United States of America       AMRO
# 104968    2020-01-04           US  United States of America       AMRO
# 104969    2020-01-05           US  United States of America       AMRO
# 104970    2020-01-06           US  United States of America       AMRO
# 104971    2020-01-07           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 105429    2021-04-09           US  United States of America       AMRO
# 105430    2021-04-10           US  United States of America       AMRO
# 105431    2021-04-11           US  United States of America       AMRO
# 105432    2021-04-12           US  United States of America       AMRO
# 105433    2021-04-13           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
cov[cov['New_deaths']>1000]
# Out:
#        Date_reported Country_code                           Country  \
# 4006      2020-10-03           AR                         Argentina
# 11447     2020-09-08           BO  Bolivia (Plurinational State of)
# 13203     2020-05-21           BR                            Brazil
# 13205     2020-05-23           BR                            Brazil
# 13206     2020-05-24           BR                            Brazil
# ...              ...          ...                               ...
# 105415    2021-03-26           US          United States of America
# 105416    2021-03-27           US          United States of America
# 105417    2021-03-28           US          United States of America
# 105422    2021-04-02           US          United States of America
# 105424    2021-04-04           US          United States of America
#
#        WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
cov.loc[cov['New_deaths']>1000,['New_deaths','Country']]
# Out:
#         New_deaths                           Country
# 4006          3351                         Argentina
# 11447         1610  Bolivia (Plurinational State of)
# 13203         1179                            Brazil
# 13205         1188                            Brazil
# 13206         1001                            Brazil
# ...            ...                               ...
# 105415        1293          United States of America
# 105416        1403          United States of America
# 105417        1280          United States of America
# 105422        1055          United States of America
# 105424        2655          United States of America
#
# [512 rows x 2 columns]
